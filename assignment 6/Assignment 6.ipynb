# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#importing the necessary libraries for plotting
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.gridspec import GridSpec
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt; plt.rcdefaults()

#importing numpy and panda
import numpy as np
import pandas as pd

# %%
import pandas as pd
df1=pd.read_excel("customer_retention_dataset.xlsx",sheet_name='datasheet')

# %%
df1.columns = map(lambda s:s.strip(), df1.columns)
pd.set_option('display.max_columns', None)
df1
# Out:
#     Gender of respondent                 Age           city  Pin Code  \
# 0                   Male         31-40 years          Delhi    110009
# 1                 Female         21-30 years          Delhi    110030
# 2                 Female         21-30 years  Greater Noida    201308
# 3                   Male         21-30 years        Karnal     132001
# 4                 Female         21-30 years     Bangalore     530068
# ..                   ...                 ...            ...       ...
# 264               Female         21-30 years          Solan    173212
# 265               Female         31-40 years      Ghaziabad    201008
# 266               Female         41-50 yaers     Bangalore     560010
# 267               Female  Less than 20 years          Solan    173229
# 268               Female         41-50 yaers      Ghaziabad    201009
#
#     Duration since Shopping Online  \
# 0                    Above 4 years
# 1                    Above 4 years
# ...

# %% [markdown]
# # Analytical Modeling of the Problem

# %% [markdown]
# Problem in hand:
#
# Customer satisfaction is the problem in hand. This customer satisfaction can impact the cutomer retention to large extend. Hence Through our project we will find out the factors of cutomer satisfaction

# %%
import pandas as pd
df=pd.read_excel("customer_retention_dataset.xlsx", sheet_name='codedsheet')

df.columns = map(lambda s:s.strip(), df1.columns)
pd.set_option('display.max_columns', None)
df
# Out:
#      Gender of respondent  Age           city  Pin Code  \
# 0                       0    3          Delhi    110009
# 1                       1    2          Delhi    110030
# 2                       1    2  Greater Noida    201308
# 3                       0    2        Karnal     132001
# 4                       1    2     Bangalore     530068
# ..                    ...  ...            ...       ...
# 264                     1    2          Solan    173212
# 265                     1    3      Ghaziabad    201008
# 266                     1    4     Bangalore     560010
# 267                     1    1          Solan    173229
# 268                     1    4      Ghaziabad    201009
#
#      Duration since Shopping Online  \
# 0                                 5
# 1                                 5
# 2                                 4
# 3                                 4
# 4                                 3
# ..                              ...
# ...

# %% [markdown]
# # EDA

# %%
#understanding the data
df.describe()
# Out:
#        Gender of respondent         Age       Pin Code  \
# count            269.000000  269.000000     269.000000
# mean               0.669145    2.959108  220465.747212
# std                0.471398    1.066012  140524.341051
# min                0.000000    1.000000  110008.000000
# 25%                0.000000    2.000000  122018.000000
# 50%                1.000000    3.000000  201303.000000
# 75%                1.000000    4.000000  201310.000000
# max                1.000000    5.000000  560037.000000
#
#        Duration since Shopping Online  \
# count                      269.000000
# mean                         3.524164
# std                          1.436586
# min                          1.000000
# 25%                          3.000000
# 50%                          4.000000
# 75%                          5.000000
# max                          5.000000
#
#        times have made an online purchase in the past 1 year  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

lab_enc=LabelEncoder()
df2=lab_enc.fit_transform(df["Which of the Indian online retailer would you recommend to a friend?"])
pd.Series(df2)
# Out:
# 0      6
# 1      3
# 2      5
# 3      1
# 4      3
#       ..
# 264    0
# 265    6
# 266    0
# 267    0
# 268    0
# Length: 269, dtype: int32

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# # 1.Respondents details

# %%
#female
df1['Gender of respondent'].hist(figsize=(5,2),bins = 15,color='g')
plt.title("Gender of respondent")
plt.show()


#age
df1['Age'].hist(figsize=(10,2),bins = 25,color='r')
plt.title("Age")
plt.show()


#gender and preference
plt.figure(figsize=(7,3))
sns.lineplot(x="Which of the Indian online retailer would you recommend to a friend?",y="Gender of respondent",data=df1,color='y')
plt.show()

#gender and preference
plt.figure(figsize=(7,3))
sns.lineplot(x="Which of the Indian online retailer would you recommend to a friend?",y="Age",data=df1)
plt.show()

# %% [markdown]
# higher respondents are female

# %% [markdown]
# 81 or highest is in 31-40 years age group. The least respondents are in the 51years and above age group

# %% [markdown]
# # System Quality/Details of device/internet used to do online shopping:
#
# System details:accessed internet via what internet,accessing the internet while shopping on-line,screen size of your mobile device,operating system (OS),browser,channel did you follow to arrive at your favorite online store for the first time,

# %%
#A.accessing the internet while shopping on-line
df1['accessing the internet while shopping online'].hist(figsize=(5,2),bins = 15,color='r')
plt.title("accessing the internet while shopping online")
plt.show()

#B.device to access the online shopping
df1['device to access the online shopping'].hist(figsize=(5,2),bins = 15,color='y')
plt.title("device to access the online shopping")
plt.show()

#C.screen size of your mobile device
print(df1["screen size of your mobile device"].value_counts())
df['screen size of your mobile device'].hist(figsize=(5,2),bins = 15,color='pink')
plt.title("screen size of your mobile device")
plt.show()

#D.operating system (OS)
print(df1["operating system (OS)"].value_counts())
df1['operating system (OS)'].hist(figsize=(5,2),bins = 15,color='purple')
plt.title("operating system (OS)")
plt.show()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: screen size of your mobile device, dtype: int64
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: operating system (OS), dtype: int64

# %% [markdown]
# Observation:
#
# 1.The maximum people accessed via Mobile internet and least via dial up
#
# 2.Largest number of online shopping done through Smartphone and least through tablet
#
# 3.Others is highest with 134 respondents for the device size
#
# 4.Maximum OS used are Windows
#
# Conclusion:
#
# Our online shopping website should be most suited for Mobile internet accessible,Smart phone adaptable,allowing devices of different screen sizes to view comfortably.

# %%
#Which of the Indian online retailer would you recommend to a friend?

plt.figure(figsize=(5,3))
sns.lineplot(x="Which of the Indian online retailer would you recommend to a friend?",y="accessing the internet while shopping online",data=df1,color='r')
plt.show()

plt.figure(figsize=(5,3))
sns.lineplot(x="Which of the Indian online retailer would you recommend to a friend?",y="device to access the online shopping",data=df1,color='purple')
plt.show()

plt.figure(figsize=(5,3))
sns.lineplot(x="Which of the Indian online retailer would you recommend to a friend?",y="screen size of your mobile device",data=df1,color='grey')
plt.show()

plt.figure(figsize=(5,3))
sns.lineplot(x="Which of the Indian online retailer would you recommend to a friend?",y="operating system (OS)",data=df1,color='green')
plt.show()

# %% [markdown]
# Observations:
#
# 1.Device usage:
#
# A.The respondent who would prefer amazon alone used -smartphone,4.7 inches mobile device and windows/IOS
#
# B.The respondent who would prefer flipkart alone used -smartphone and tablet,not 4.7 inches/5.5 inches mobile device and windows
#
# C.The respondent who would prefer both amazon and flipkart used -tablet,4.7 inches mobile device and IOS
#
# D.The respondent who would prefer both amazon and myntra used -tablet,4.7 inches mobile device and IOS
#
# E.The respondent who would prefer both amazon and paytm used -smartphone,5.5 inches mobile device and android
#
# F.The respondent who would prefer amazon,myntra and flipkart used -laptop,not 4.7 inches/5.5 inches mobile device and Windows
#
# G.The respondent who would prefer amazon,myntra and paytm used -smartphone,5.5 inches mobile device and android

# %%
#Easy to use website or application
plt.figure(figsize=(9,5))
sns.lineplot(x="Easy to use website or application",y="device to access the online shopping",data=df1)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Process/route of customer activation

# %%
#A.channel did you follow to arrive at your favorite online store for the first time

print(df1["channel did you follow to arrive at your favorite online store for the first time"].value_counts())


df1['channel did you follow to arrive at your favorite online store for the first time'].hist(figsize=(5,2),bins = 15)
plt.title("channel did you follow to arrive at your favorite online store for the first time")
plt.show()


plt.plot(df1["channel did you follow to arrive at your favorite online store for the first time"], df1["Age"])
plt.title("Method to come first time vs Age")
plt.xlabel("Method to come first time")
plt.ylabel("Age")
plt.show()

plt.plot(df1["channel did you follow to arrive at your favorite online store for the first time"], df1["Gender of respondent"])
plt.title("Method to come first time vs Age")
plt.xlabel("Method to come first time")
plt.ylabel("Gender of respondent")
plt.show()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: channel did you follow to arrive at your favorite online store for the first time, dtype: int64

# %% [markdown]
# Observations:
#
# 1.It is through search engines the maximum people will reach the online shopping website
#
# 2.The 41-50years and 21-30years groups have depended on Display Adverts more
#
# 3.Male and female have equally used all the methods

# %%
#B.time in exploring before making decision

print(df1["time in exploring before making decision"].value_counts())

df['time in exploring before making decision'].hist(figsize=(5,2),bins = 15)
plt.title("time in exploring before making decision")
plt.show()


plt.bar(df1["time in exploring before making decision"], df1["preferred payment Option"],color='g')
plt.title("time in exploring before making decision vs preferred payment Option")
plt.xlabel("time in exploring before making decision")
plt.ylabel("preferred payment Option")
plt.show()

plt.bar(df1["time in exploring before making decision"], df1["frequency of abandoning cart"],color='r')
plt.title("time in exploring before making decision vs frequency of abandoning cart")
plt.xlabel("time in exploring before making decision")
plt.ylabel("frequency of abandoning cart")
plt.show()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: time in exploring before making decision, dtype: int64

# %% [markdown]
# Observation:
#
# 1.More than 15minutes are taken by maximum respondents before taking a decision
#
# 2.Mode of payment does not matter on the time they take on making decision
#
# 3.If they take 11-15min or 15min and above, there is highest chances of abandoning the basket. Whereas the people 1-5min have least tendency to adandon the basket. This shows that a count down saver timer would be benfecial to avoid dropping of the basket

# %% [markdown]
# # Factors hindering the customer activation

# %%
#A.Abadoning the basket
print(df1["Reason for abandoning the “Bag”, “Shopping Cart”"].value_counts())

df1['Reason for abandoning the “Bag”, “Shopping Cart”'].hist(figsize=(10,5),bins = 15)
plt.title("Reason for abandoning the bag")
plt.show()

plt.rcParams["figure.figsize"] = (10, 2)
plt.bar(df1["Reason for abandoning the “Bag”, “Shopping Cart”"], df1["frequency of abandoning cart"])
plt.title("Reason for abandoning the bag vs frequency of abandoning cart")
plt.xlabel("time in exploring before making decision")
plt.ylabel("Reason for abandoning the bag")
plt.show()

df1.groupby('Reason for abandoning the “Bag”, “Shopping Cart”').size().plot(kind='pie', autopct='%.2f')
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: Reason for abandoning the “Bag”, “Shopping Cart”, dtype: int64
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# Observation:
#
# 1.Maximum people and the highest frequency of dropping the bag is because of Better alternative
#
# 2.Promo code not applicable is the next highest reason
#
# 3.However lack of trust/change in price/No preferred mode of payment is rarely a reason to drop the bag

# %% [markdown]
# #  After first visit, how do you reach the online retail store

# %%
print(df1["After first visit, how do you reach the online retail store"].value_counts())


df1['After first visit, how do you reach the online retail store'].hist(figsize=(5,2),bins = 15)
plt.title("After first visit, how do you reach the online retail store")
plt.show()



plt.bar(df1["After first visit, how do you reach the online retail store"], df1["Age"],color='g')
plt.title("Method to come Second time vs Age")
plt.xlabel("Method to come Second time")
plt.ylabel("Age")
plt.show()
color='g'


plt.scatter(df1["After first visit, how do you reach the online retail store"], df1["Gender of respondent"],color='r')
plt.title("Method to come Second  time vs Age")
plt.xlabel("Method to come Second  time")
plt.ylabel("Gender of respondent")
plt.show()


df1.groupby('After first visit, how do you reach the online retail store').size().plot(kind='pie', autopct='%.2f')
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: After first visit, how do you reach the online retail store, dtype: int64
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# Observation:
#
# 1.In the second time, the method has search engines usage but also an equal usage of Via application
#
# 2.Social media is of least significance is all age groups
#
# 3.All methods the same in both male and female for second time

# %% [markdown]
# #    Product Information/Information Quality

# %%
#Product Information-readability and every detail stated sepecifically

#readbility
plt.hist(df1["content on the website readability important for purchase decision"])
plt.title("content on the website readability important for purchase decision")
plt.show()

plt.bar(df1["content on the website readability important for purchase decision"], df1["frequency of abandoning cart"],color='g')
plt.title("content on the website readability important for purchase decision vs frequency of abandoning cart")
plt.xlabel("website readability")
plt.ylabel("frequency of abandoning cart")
plt.show()

plt.figure(figsize=(7,3))
sns.lineplot(x="Which of the Indian online retailer would you recommend to a friend?",y="content on the website readability important for purchase decision",data=df1)
plt.show()

df1.groupby('content on the website readability important for purchase decision').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# The readability of the product information is very significant as above 164 people have expressed how important it is to them.If not readable they are abandoning the bag

# %%
#All relevant information on listed products must be stated clearly
print(df1["All relevant information on listed products must be stated clearly"].value_counts())


df1['All relevant information on listed products must be stated clearly'].hist(figsize=(7,4),bins = 12)
plt.title("All relevant information on listed products must be stated clearly")
plt.show()

plt.bar(df1["All relevant information on listed products must be stated clearly"], df1["frequency of abandoning cart"],color='g')
plt.title("All relevant information on listed products must be stated clearly vs frequency of abandoning cart")
plt.xlabel("All relevant details listed specifically")
plt.ylabel("frequency of abandoning cart")
plt.show()
color='r'

df1.groupby('All relevant information on listed products must be stated clearly').size().plot(kind='pie', autopct='%.2f')
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: All relevant information on listed products must be stated clearly, dtype: int64
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# The DETAILS of the product information is very significant as above 132 people have expressed how important it is to them.If details are not proper then they are abandoning the bag

# %%
#Provision of complete and relevant product information
plt.hist(df1["Provision of complete and relevant product information"],color='black')
plt.title("Provision of complete and relevant product information")
plt.show()


#Complete, relevant description information of products websites/apps
plt.hist(df1["Complete, relevant description information of products"],color='pink')
plt.title("Complete, relevant description information of products")
plt.show()


sns.barplot(x ='User friendly Interface of the website', y ='Complete, relevant description information of products', data = df, palette ='plasma')
# Out:
# <AxesSubplot:xlabel='User friendly Interface of the website', ylabel='Complete, relevant description information of products'>

# %% [markdown]
# Flipkart gives the best description and then Amazon

# %%
#Visual appealing web-page layout

print(df1["Visual appealing web-page layout"].value_counts())


df1['Visual appealing web-page layout'].hist(figsize=(10,5),bins = 15)
plt.title("Visual appealing web-page layout")
plt.show()

sns.barplot(x ='User friendly Interface of the website', y ='Visual appealing web-page layout', data = df, palette ='plasma')

plt.figure(figsize=(5,3))
sns.lineplot(x="Which of the Indian online retailer would you recommend to a friend?",y="Visual appealing web-page layout",data=df1)
plt.show()
# Out:
# A, F             87
# A                44
# A, F, P, M, S    36
# A, P, M          20
# M                15
# F, M             15
# A, M             14
# A, F, M, S       14
# F                12
# A, F, P, S       11
# , M               1
# Name: Visual appealing web-page layout, dtype: int64

# %% [markdown]
# Amazon and flipkart are having the best visual layout.
#
# However the visual appealing is impacting the User Friendly intercace of the website
#
# Visual layout is not having much impact in choosing the website again

# %% [markdown]
# #     Convinence
#
# Consists of:
#
# 1.Website interface related
#
# 2.checking other products available next to product
#
# 3.User friendly websites
#
# 4.Frequent disruption when moving from one page to another
#
# 5.Quickness to complete purchase
#
# 6.Payment methods

# %%
#Ease of navigation in website
print(df1["Ease of navigation in website"].value_counts())


df1['Ease of navigation in website'].hist(figsize=(5,2),bins = 15)
plt.title("Ease of navigation in websiten")
plt.show()

plt.bar(df1["Ease of navigation in website"], df1["frequency of abandoning cart"],color='g')
plt.title("Ease of navigation in website vs frequency of abandoning cart")
plt.xlabel("Ease of navigation in website")
plt.ylabel("frequency of abandoning cart")
plt.show()
color='g'


#Frequent disruption when moving from one page to another
df1['Frequent disruption when moving from one page to another'].hist(figsize=(5,2),bins = 15)
plt.title("Frequent disruption when moving from one page to another")
plt.show()

sns.barplot(x ='User friendly Interface of the website', y ='Frequent disruption when moving from one page to another', data = df, palette ='plasma')
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: Ease of navigation in website, dtype: int64
# <AxesSubplot:xlabel='User friendly Interface of the website', ylabel='Frequent disruption when moving from one page to another'>

# %% [markdown]
# The website interface is more important than the product details are per the respondents

# %%
#most user friendly websites
df1['User friendly Interface of the website'].hist(figsize=(7,3),bins = 15,color='red')
plt.title("User friendly Interface of the website")
plt.show()

#User friendly Interface of the website
df1['Ease of navigation in website'].hist(figsize=(7,3),bins = 15,color='yellow')
plt.title("Ease of navigation in websiten")
plt.show()

df1['Easy to use website or application'].hist(figsize=(7,3),bins = 15,color='green')
plt.title("Easy to use website or application")
plt.show()


sns.barplot(x ='User friendly Interface of the website', y ='Easy to use website or application', data = df, palette ='plasma')
# Out:
# <AxesSubplot:xlabel='User friendly Interface of the website', ylabel='Easy to use website or application'>

# %% [markdown]
# Some people are indifferent to it and a few disagree to it as well. However the largest section of respondent strongly agree or agree that user friendly websites impacts in taking decisions

# %% [markdown]
# Amazon can be seen as the best interface website

# %%
#Flexibility in shopping online
plt.hist(df1["Flexibility in shopping online"],color='g')
plt.title("Flexibility in shopping online")
plt.show()

# %% [markdown]
# Maximum disruptions is seen in Paytm

# %%
#Longer time to get logged in (promotion, sales period)
df1['Longer time to get logged in (promotion, sales period)'].hist(figsize=(7,4),bins = 15,color='yellow')
plt.title("Longer time to get logged in (promotion, sales period)")
plt.show()

#Fast loading website speed of website and application
df1['Fast loading website speed of website and application'].hist(figsize=(7,4),bins = 15,color='red')
plt.title("Fast loading website speed of website and application")
plt.show()

#Longer time in displaying graphics and photos (promotion, sales period)
df1['Longer time in displaying graphics and photos (promotion, sales period)'].hist(figsize=(7,4),bins = 15,color='yellow')
plt.title("Longer time in displaying graphics and photos (promotion, sales period)")
plt.show()

#Late declaration of price (promotion, sales period)
df1['Late declaration of price (promotion, sales period)'].hist(figsize=(7,4),bins = 15,color='red')
plt.title("Late declaration of price (promotion, sales period)")
plt.show()

# %% [markdown]
# Amazon gets maximum time to get logged into

# %% [markdown]
# Paytm is the fastest loading website

# %%
#Availability of several payment options
df1['Availability of several payment options'].hist(figsize=(8,4),bins = 15,color='red')
plt.title("Availability of several payment options")
plt.show()


#preferred payment Option
df1['preferred payment Option'].hist(figsize=(8,4),bins = 15,color='green')
plt.title("preferred payment Option")
plt.show()

#Quickness to complete purchase
plt.hist(df1["Quickness to complete purchase"],color='red')
plt.title("Quickness to complete purchase")
plt.show()

# %%
#Speedy order delivery
plt.hist(df1["Speedy order delivery"],color='pink')
plt.title("Speedy order delivery")
plt.show()

# %% [markdown]
# #  Monetary savings/Net benefit

# %%
#Product comparison methods available

plt.bar(df1["Information on similar product to the one highlighted  is important for product comparison"], df1["frequency of abandoning cart"],color='g')
plt.title("Information on similar product to the one highlighted is important for product comparison vs frequency of abandoning cart")
plt.xlabel("Product comparison methods available")
plt.ylabel("frequency of abandoning cart")
plt.show()
color='g'


plt.hist(df1["Information on similar product to the one highlighted  is important for product comparison"])
plt.title("Information on similar product to the one highlighted  is important for product comparison")
plt.show()

# %% [markdown]
# It is very significant to show similar products descriptions as more than 70% have agreed to it

# %%
#monetary benefit and discounts in online shopping
print(df1["monetary benefit and discounts in online shopping"].value_counts())
plt.hist(df1["monetary benefit and discounts in online shopping"])
plt.title("monetary benefit and discounts in online shopping")
plt.show()

#Gaining access to loyalty programs is a benefit of shopping online
plt.hist(df1["Gaining access to loyalty programs is a benefit of shopping online"],color='g')
plt.title("Gaining access to loyalty programs is a benefit of shopping online")
plt.show()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: monetary benefit and discounts in online shopping, dtype: int64

# %% [markdown]
# Eventhough a large group of people are drawn towards online shopping through discounts and loyalty shopping, a large group of people are indifferent to it

# %% [markdown]
# # Product offers

# %%
#Wild variety of product on offer
print(df1["Wild variety of product on offer"].value_counts())
plt.hist(df1["Wild variety of product on offer"])
plt.title("Wild variety of product on offer")
plt.show()
# Out:
# A, F          130
# A              43
# A, M           20
# M              15
# F, M           15
# A, F, M, S     14
# A, F, P        13
# F              12
# P               7
# Name: Wild variety of product on offer, dtype: int64

# %% [markdown]
# Amazon and flipkart offers the widest varieties

# %% [markdown]
# # PRIVACY

# %%
#Being able to guarantee the privacy of the customer
print(df1["Being able to guarantee the privacy of the customer"].value_counts())
plt.hist(df1["Being able to guarantee the privacy of the customer"])
plt.title("Being able to guarantee the privacy of the customer")
plt.show()


#Privacy of customers’ information
plt.hist(df1["Privacy of customers’ information"])
plt.title("Privacy of customers’ information")
plt.show()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: Being able to guarantee the privacy of the customer, dtype: int64

# %% [markdown]
# It is very important for an individual to have privacy and the highest privacy is seen in amazon

# %%
#Security of customer financial information
plt.hist(df1["Security of customer financial information"],color='g')
plt.title("Security of customer financial information")
plt.show()

#Perceived Trustworthiness
plt.hist(df1["Perceived Trustworthiness"],color='r')
plt.title("Perceived Trustworthiness")
plt.show()

#

# %% [markdown]
# # TRUST

# %%
#Perceived Trustworthiness
plt.hist(df1["Trust that the online retail store will fulfill its part of the transaction at the stipulated time"],color='y')
plt.title("Trust that the online retail store will fulfill its part of the transaction at the stipulated time")
plt.show()

#Perceived Trustworthiness
plt.hist(df1["Perceived Trustworthiness"],color='r')
plt.title("Perceived Trustworthiness")
plt.show()

#User satisfaction cannot exist without trust
plt.hist(df1["User satisfaction cannot exist without trust"],color='black')
plt.title("User satisfaction cannot exist without trust")
plt.show()

# %%
#Quickness to complete purchase
plt.hist(df1["Quickness to complete purchase"],color='black')
plt.title("Quickness to complete purchase")
plt.show()

# %% [markdown]
# User satisfaction is directly proportional to trust that the product will be delivered in the proper amount of time

# %% [markdown]
# # Customer care

# %%
#Responsiveness/availability of several communication channels
plt.hist(df1["Responsiveness/availability of several communication channels"],color='r')
plt.title("Responsiveness/availability of several communication channels")
plt.show()

#Presence of online assistance through multi-channel
plt.hist(df1["Presence of online assistance through multi-channel"],color='g')
plt.title("Presence of online assistance through multi-channel")
plt.show()

# %%
#Empathy (readiness to assist with queries) towards the customers
plt.hist(df1["Empathy (readiness to assist with queries) towards the customers"],color='g')
plt.title("Empathy (readiness to assist with queries) towards the customersl")
plt.show()

# %% [markdown]
# # Gratification

# %%
#Enjoyment in shopping online
plt.hist(df1["Enjoyment in shopping online"],color='y')
plt.title("Enjoyment in shopping online")
plt.show()


#Return and replacement policy of the e-tailer is important for purchase decision
plt.hist(df1["Return and replacement policy of the e-tailer is important for purchase decision"],color='r')
plt.title("Return and replacement policy of the e-tailer is important for purchase decision")
plt.show()

# %% [markdown]
# There is a large section of respondents who are indifferent about shopping online and also many who strongly disagree that enjoyment is not present in shopping online

# %%
#Gratification depends on quality information and website quality

#Displaying quality Information on the website improves satisfaction of customers
plt.hist(df1["Displaying quality Information on the website improves satisfaction of customers"],color='black')
plt.title("Displaying quality Information on the website improves satisfaction of customers")
plt.show()


#User derive satisfaction while shopping on a good quality website or application
plt.hist(df1["User derive satisfaction while shopping on a good quality website or application"],color='orange')
plt.title("User derive satisfaction while shopping on a good quality website or application")
plt.show()

# %%
df1.groupby('User derive satisfaction while shopping on a good quality website or application').size().plot(kind='pie', autopct='%.2f')
plt.title("User derive satisfaction while shopping on a good quality website or application pie chart")

df1.groupby('Displaying quality Information on the website improves satisfaction of customers').size().plot(kind='pie', autopct='%.2f')
plt.title("Displaying quality Information on the website improves satisfaction of customers pie",bbox={'facecolor':'0.8', 'pad':5})
# Out:
# Text(0.5, 1.0, 'Displaying quality Information on the website improves satisfaction of customers pie')

# %%
#You feel gratification shopping on your favorite e-tailer
plt.hist(df1["You feel gratification shopping on your favorite e-tailer"],color='maroon')
plt.title("You feel gratification shopping on your favorite e-tailer")
plt.show()

df1.groupby('You feel gratification shopping on your favorite e-tailer').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# Mostly people dont get affected emotionally by which online store they buy from as they have no much attachment to it

# %% [markdown]
# # Best Deal

# %%
#best deal

#Offering a wide variety of listed product in several category
plt.hist(df1["Offering a wide variety of listed product in several category"],color='pink')
plt.title("Offering a wide variety of listed product in several category")
plt.show()

df1.groupby('Offering a wide variety of listed product in several category').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
#Wild variety of product on offer
plt.hist(df1["Wild variety of product on offer"],color='green')
plt.title("Wild variety of product on offer")
plt.show()

# %% [markdown]
# Wide variety of products to choose from is siginificant for taking decisions

# %% [markdown]
# # Social

# %%
#The Convenience of patronizing the online retailer
plt.hist(df1["The Convenience of patronizing the online retailer"],color='orange')
plt.title("The Convenience of patronizing the online retailer")
plt.show()

df1.groupby('The Convenience of patronizing the online retailer').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
#Shopping on your preferred e-tailer enhances your social status
plt.hist(df1["Shopping on your preferred e-tailer enhances your social status"],color='purple')
plt.title("Shopping on your preferred e-tailer enhances your social status")
plt.show()

df1.groupby('Shopping on your preferred e-tailer enhances your social status').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# # Adventure

# %%
#hopping on the website gives you the sense of adventure
plt.hist(df1["hopping on the website gives you the sense of adventure"],color='grey')
plt.title("hopping on the website gives you the sense of adventure")
plt.show()

df1.groupby('hopping on the website gives you the sense of adventure').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# Eventhough some respondents respond they come into the website for adventure in some small sense. But There is also a large number of respondent were indifferent to it

# %% [markdown]
# # Role

# %%
#Shopping on the website helps you fulfill certain roles
plt.hist(df1["Shopping on the website helps you fulfill certain roles"],color='grey')
plt.title("Shopping on the website helps you fulfill certain roles")
plt.show()

df1.groupby('Shopping on the website helps you fulfill certain roles').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>
